# %% [markdown]
# ## Initial Setup & Imports

# %%
import numpy
print numpy.__version__
# Out:
# 1.11.1

# %%
from pyalgotrade import strategy
from pyalgotrade.barfeed import yahoofeed

# %% [markdown]
# ## Parse Date Function

# %%
def parse_date(date):
    return datetime.datetime.strptime(date, "%m/%d/%Y")

# %% [markdown]
# ## RowParser
#
# This class parses a single-row of the CBOE raw future file
#
# First couple of lines:
#
# ```
# CFE data is compiled for the convenience of site visitors and is furnished without responsibility for accuracy and is accepted by the site visitor on the condition that transmission or omissions shall not be made the basis for any claim demand or cause for action. The information and data was obtained from sources believed to be reliable but accuracy is not guaranteed. Your use of CFE data is subject to the Terms and Conditions of CBOE's Websites.
# Trade Date,Futures,Open,High,Low,Close,Settle,Change,Total Volume,EFP,Open Interest
# 04/20/2015,F (Jan 16),0.00,18.95,0.00,0.00,18.9750,18.98,0,0,0
# ```
#
# See ```parseBar``` for the mapping of csv columns to the ```bar.BasicBar``` of PyAlgoTrade.

# %%
from pyalgotrade.barfeed import csvfeed

class RowParser(csvfeed.RowParser):
    def __init__(self, dailyBarTime, frequency, timezone=None, sanitize=False):
        self.__dailyBarTime = dailyBarTime
        self.__frequency = frequency
        self.__timezone = timezone
        self.__sanitize = sanitize

    def __parseDate(self, dateString):
        ret = parse_date(dateString)
        # Time on Yahoo! Finance CSV files is empty. If told to set one, do it.
        if self.__dailyBarTime is not None:
            ret = datetime.datetime.combine(ret, self.__dailyBarTime)
        # Localize the datetime if a timezone was given.
        if self.__timezone:
            ret = dt.localize(ret, self.__timezone)
        return ret

    def getFieldNames(self):
        # It is expected for the first row to have the field names.
        return None

    def getDelimiter(self):
        return ","

    def parseBar(self, csvRowDict):
        dateTime = self.__parseDate(csvRowDict["Trade Date"])
        close = float(csvRowDict["Close"])
        open_ = float(csvRowDict["Open"])
        high = float(csvRowDict["High"])
        low = float(csvRowDict["Low"])
        volume = float(csvRowDict["Total Volume"])
        adjClose = float(csvRowDict["Close"])

        if self.__sanitize:
            open_, high, low, close = common.sanitize_ohlc(open_, high, low, close)
        
        if high < low: #fix for bad bars where the open interest is 0, and you have weird conditions
            return None
        
        return bar.BasicBar(dateTime, open_, high, low, close, volume, adjClose, self.__frequency)

# %% [markdown]
# ## Fetch the CSV File and Sanitizing It

# %%
import urllib2
response = urllib2.urlopen('http://cfe.cboe.com/Publish/ScheduledTask/MktData/datahouse/CFE_F16_VX.csv')
html = response.read()
html_processed = "\n".join(html.split("\n")[1:])
print html_processed

filename = "sanitized_vix.csv"
target = open(filename, 'w')
target.write(html_processed)
target.close()
# Out:
# Trade Date,Futures,Open,High,Low,Close,Settle,Change,Total Volume,EFP,Open Interest
# 04/20/2015,F (Jan 16),0.00,18.95,0.00,0.00,18.9750,18.98,0,0,0
# 04/21/2015,F (Jan 16),0.00,19.05,19.65,0.00,19.3500,0.38,0,0,0
# 04/22/2015,F (Jan 16),0.00,19.20,19.25,0.00,19.1500,-0.20,0,0,0
# 04/23/2015,F (Jan 16),0.00,19.10,19.25,0.00,19.1750,0.02,0,0,0
# 04/24/2015,F (Jan 16),19.15,19.15,19.15,19.15,19.1750,0.00,2,0,2
#def addBarsFromCSV(self, instrument, path, rowParser):

path = filename
rowParser =  RowParser(datetime.time(0, 0, 0), bar.Frequency.DAY, None, False)

loadedBars = []
reader = csvutils.FastDictReader(open(path, "r"), fieldnames=rowParser.getFieldNames(), delimiter=rowParser.getDelimiter())
for row in reader:
    bar_ = rowParser.parseBar(row)
    
    if bar_ is not None:
        loadedBars.append(bar_)


print "Length of Loaded Bars:"
print len(loadedBars)

print "First Bar:"
print loadedBars[0].__getstate__()
# Out:
# Length of Loaded Bars:
# 188
# First Bar:
# (datetime.datetime(2015, 4, 20, 0, 0), 0.0, 0.0, 18.95, 0.0, 0.0, 0.0, 86400, False)

# %% [markdown]
# ## Create a PyAlgoFeed Feed and Strategy

# %%
from pyalgotrade.barfeed import common
from pyalgotrade.utils import dt
from pyalgotrade import bar
from pyalgotrade import dataseries

class Feed(csvfeed.BarFeed):
    """A :class:`pyalgotrade.barfeed.csvfeed.BarFeed` that loads bars from CSV files downloaded from Yahoo! Finance.

    :param frequency: The frequency of the bars. Only **pyalgotrade.bar.Frequency.DAY** or **pyalgotrade.bar.Frequency.WEEK**
        are supported.
    :param timezone: The default timezone to use to localize bars. Check :mod:`pyalgotrade.marketsession`.
    :type timezone: A pytz timezone.
    :param maxLen: The maximum number of values that the :class:`pyalgotrade.dataseries.bards.BarDataSeries` will hold.
        Once a bounded length is full, when new items are added, a corresponding number of items are discarded from the opposite end.
    :type maxLen: int.

    .. note::
        Yahoo! Finance csv files lack timezone information.
        When working with multiple instruments:

            * If all the instruments loaded are in the same timezone, then the timezone parameter may not be specified.
            * If any of the instruments loaded are in different timezones, then the timezone parameter must be set.
    """

    def __init__(self, frequency=bar.Frequency.DAY, timezone=None, maxLen=dataseries.DEFAULT_MAX_LEN):
        if isinstance(timezone, int):
            raise Exception("timezone as an int parameter is not supported anymore. Please use a pytz timezone instead.")

        if frequency not in [bar.Frequency.DAY, bar.Frequency.WEEK]:
            raise Exception("Invalid frequency.")

        csvfeed.BarFeed.__init__(self, frequency, maxLen)
        self.__timezone = timezone
        self.__sanitizeBars = False

    def sanitizeBars(self, sanitize):
        self.__sanitizeBars = sanitize

    def barsHaveAdjClose(self):
        return True

    def addBarsFromCSV(self, instrument, path, timezone=None):
        """Loads bars for a given instrument from a CSV formatted file.
        The instrument gets registered in the bar feed.

        :param instrument: Instrument identifier.
        :type instrument: string.
        :param path: The path to the CSV file.
        :type path: string.
        :param timezone: The timezone to use to localize bars. Check :mod:`pyalgotrade.marketsession`.
        :type timezone: A pytz timezone.
        """

        if isinstance(timezone, int):
            raise Exception("timezone as an int parameter is not supported anymore. Please use a pytz timezone instead.")

        if timezone is None:
            timezone = self.__timezone

        rowParser = RowParser(self.getDailyBarTime(), self.getFrequency(), timezone, self.__sanitizeBars)
        csvfeed.BarFeed.addBarsFromCSV(self, instrument, path, rowParser)

# %%
from pyalgotrade import strategy 

class MyStrategy(strategy.BacktestingStrategy):
    def __init__(self, feed, instrument):
        strategy.BacktestingStrategy.__init__(self, feed)
        self.__instrument = instrument

    def onBars(self, bars):
        bar = bars[self.__instrument]
        self.info(bar.getClose())

# %%
# Load the yahoo feed from the CSV file
feed = Feed()
feed.addBarsFromCSV("VX_F", "sanitized_vix.csv")

# %%
# Evaluate the strategy with the feed's bars.
myStrategy = MyStrategy(feed, "VX_F")
myStrategy.run()
# Out:
# INFO:strategy:0.0
# 2015-04-20 00:00:00 strategy [INFO] 0.0
# INFO:strategy:19.15
# 2015-04-24 00:00:00 strategy [INFO] 19.15
# INFO:strategy:19.25
# 2015-04-27 00:00:00 strategy [INFO] 19.25
# INFO:strategy:19.1
# 2015-04-28 00:00:00 strategy [INFO] 19.1
# INFO:strategy:19.25
# 2015-04-29 00:00:00 strategy [INFO] 19.25
# INFO:strategy:19.3
# 2015-04-30 00:00:00 strategy [INFO] 19.3
# INFO:strategy:19.05
# 2015-05-01 00:00:00 strategy [INFO] 19.05
# INFO:strategy:19.2
# 2015-05-04 00:00:00 strategy [INFO] 19.2
# INFO:strategy:19.25
# 2015-05-05 00:00:00 strategy [INFO] 19.25
# INFO:strategy:19.35
# 2015-05-06 00:00:00 strategy [INFO] 19.35
# INFO:strategy:19.3
# 2015-05-07 00:00:00 strategy [INFO] 19.3
# INFO:strategy:19.1
# 2015-05-08 00:00:00 strategy [INFO] 19.1
# INFO:strategy:19.33
# 2015-05-11 00:00:00 strategy [INFO] 19.33
# INFO:strategy:19.3
# 2015-05-12 00:00:00 strategy [INFO] 19.3
# INFO:strategy:19.15
# 2015-05-13 00:00:00 strategy [INFO] 19.15
# INFO:strategy:19.04
# 2015-05-14 00:00:00 strategy [INFO] 19.04
# INFO:strategy:19.0
# 2015-05-15 00:00:00 strategy [INFO] 19.0
# INFO:strategy:18.71
# 2015-05-18 00:00:00 strategy [INFO] 18.71
# INFO:strategy:18.59
# 2015-05-19 00:00:00 strategy [INFO] 18.59
# INFO:strategy:18.63
# 2015-05-20 00:00:00 strategy [INFO] 18.63
# INFO:strategy:18.5
# 2015-05-21 00:00:00 strategy [INFO] 18.5
# INFO:strategy:18.6
# 2015-05-22 00:00:00 strategy [INFO] 18.6
# INFO:strategy:18.63
# 2015-05-26 00:00:00 strategy [INFO] 18.63
# INFO:strategy:18.55
# 2015-05-27 00:00:00 strategy [INFO] 18.55
# INFO:strategy:18.6
# 2015-05-28 00:00:00 strategy [INFO] 18.6
# INFO:strategy:18.71
# 2015-05-29 00:00:00 strategy [INFO] 18.71
# INFO:strategy:18.56
# 2015-06-01 00:00:00 strategy [INFO] 18.56
# INFO:strategy:18.79
# 2015-06-02 00:00:00 strategy [INFO] 18.79
# INFO:strategy:18.63
# 2015-06-03 00:00:00 strategy [INFO] 18.63
# INFO:strategy:18.84
# 2015-06-04 00:00:00 strategy [INFO] 18.84
# INFO:strategy:18.85
# 2015-06-05 00:00:00 strategy [INFO] 18.85
# INFO:strategy:19.04
# 2015-06-08 00:00:00 strategy [INFO] 19.04
# INFO:strategy:18.9
# 2015-06-09 00:00:00 strategy [INFO] 18.9
# INFO:strategy:18.55
# 2015-06-10 00:00:00 strategy [INFO] 18.55
# INFO:strategy:18.45
# 2015-06-11 00:00:00 strategy [INFO] 18.45
# INFO:strategy:18.55
# 2015-06-12 00:00:00 strategy [INFO] 18.55
# INFO:strategy:18.85
# 2015-06-15 00:00:00 strategy [INFO] 18.85
# INFO:strategy:18.75
# 2015-06-16 00:00:00 strategy [INFO] 18.75
# INFO:strategy:18.75
# 2015-06-17 00:00:00 strategy [INFO] 18.75
# INFO:strategy:18.46
# 2015-06-18 00:00:00 strategy [INFO] 18.46
# INFO:strategy:18.61
# 2015-06-19 00:00:00 strategy [INFO] 18.61
# INFO:strategy:18.18
# 2015-06-22 00:00:00 strategy [INFO] 18.18
# INFO:strategy:18.05
# 2015-06-23 00:00:00 strategy [INFO] 18.05
# INFO:strategy:18.15
# 2015-06-24 00:00:00 strategy [INFO] 18.15
# INFO:strategy:18.18
# 2015-06-25 00:00:00 strategy [INFO] 18.18
# INFO:strategy:18.05
# 2015-06-26 00:00:00 strategy [INFO] 18.05
# INFO:strategy:18.82
# 2015-06-29 00:00:00 strategy [INFO] 18.82
# INFO:strategy:18.7
# 2015-06-30 00:00:00 strategy [INFO] 18.7
# INFO:strategy:17.97
# 2015-07-01 00:00:00 strategy [INFO] 17.97
# INFO:strategy:18.35
# 2015-07-02 00:00:00 strategy [INFO] 18.35
# INFO:strategy:18.65
# 2015-07-06 00:00:00 strategy [INFO] 18.65
# INFO:strategy:18.3
# 2015-07-07 00:00:00 strategy [INFO] 18.3
# INFO:strategy:18.9
# 2015-07-08 00:00:00 strategy [INFO] 18.9
# INFO:strategy:19.22
# 2015-07-09 00:00:00 strategy [INFO] 19.22
# INFO:strategy:18.65
# 2015-07-10 00:00:00 strategy [INFO] 18.65
# INFO:strategy:17.85
# 2015-07-13 00:00:00 strategy [INFO] 17.85
# INFO:strategy:17.9
# 2015-07-14 00:00:00 strategy [INFO] 17.9
# INFO:strategy:17.75
# 2015-07-15 00:00:00 strategy [INFO] 17.75
# INFO:strategy:17.45
# 2015-07-16 00:00:00 strategy [INFO] 17.45
# INFO:strategy:17.5
# 2015-07-17 00:00:00 strategy [INFO] 17.5
# INFO:strategy:17.4
# 2015-07-20 00:00:00 strategy [INFO] 17.4
# INFO:strategy:17.45
# 2015-07-21 00:00:00 strategy [INFO] 17.45
# INFO:strategy:17.5
# 2015-07-22 00:00:00 strategy [INFO] 17.5
# INFO:strategy:17.5
# 2015-07-23 00:00:00 strategy [INFO] 17.5
# INFO:strategy:17.65
# 2015-07-24 00:00:00 strategy [INFO] 17.65
# INFO:strategy:17.85
# 2015-07-27 00:00:00 strategy [INFO] 17.85
# INFO:strategy:17.55
# 2015-07-28 00:00:00 strategy [INFO] 17.55
# INFO:strategy:17.5
# 2015-07-29 00:00:00 strategy [INFO] 17.5
# INFO:strategy:17.49
# 2015-07-30 00:00:00 strategy [INFO] 17.49
# INFO:strategy:17.45
# 2015-07-31 00:00:00 strategy [INFO] 17.45
# INFO:strategy:17.25
# 2015-08-03 00:00:00 strategy [INFO] 17.25
# INFO:strategy:17.35
# 2015-08-04 00:00:00 strategy [INFO] 17.35
# INFO:strategy:17.3
# 2015-08-05 00:00:00 strategy [INFO] 17.3
# INFO:strategy:17.4
# 2015-08-06 00:00:00 strategy [INFO] 17.4
# INFO:strategy:17.25
# 2015-08-07 00:00:00 strategy [INFO] 17.25
# INFO:strategy:17.18
# 2015-08-10 00:00:00 strategy [INFO] 17.18
# INFO:strategy:17.45
# 2015-08-11 00:00:00 strategy [INFO] 17.45
# INFO:strategy:17.35
# 2015-08-12 00:00:00 strategy [INFO] 17.35
# INFO:strategy:17.35
# 2015-08-13 00:00:00 strategy [INFO] 17.35
# INFO:strategy:17.25
# 2015-08-14 00:00:00 strategy [INFO] 17.25
# INFO:strategy:17.2
# 2015-08-17 00:00:00 strategy [INFO] 17.2
# INFO:strategy:17.35
# 2015-08-18 00:00:00 strategy [INFO] 17.35
# INFO:strategy:17.55
# 2015-08-19 00:00:00 strategy [INFO] 17.55
# INFO:strategy:18.15
# 2015-08-20 00:00:00 strategy [INFO] 18.15
# INFO:strategy:18.7
# 2015-08-21 00:00:00 strategy [INFO] 18.7
# INFO:strategy:20.63
# 2015-08-24 00:00:00 strategy [INFO] 20.63
# INFO:strategy:20.75
# 2015-08-25 00:00:00 strategy [INFO] 20.75
# INFO:strategy:20.15
# 2015-08-26 00:00:00 strategy [INFO] 20.15
# INFO:strategy:20.34
# 2015-08-27 00:00:00 strategy [INFO] 20.34
# INFO:strategy:21.15
# 2015-08-28 00:00:00 strategy [INFO] 21.15
# INFO:strategy:22.25
# 2015-08-31 00:00:00 strategy [INFO] 22.25
# INFO:strategy:23.98
# 2015-09-01 00:00:00 strategy [INFO] 23.98
# INFO:strategy:22.9
# 2015-09-02 00:00:00 strategy [INFO] 22.9
# INFO:strategy:23.1
# 2015-09-03 00:00:00 strategy [INFO] 23.1
# INFO:strategy:23.9
# 2015-09-04 00:00:00 strategy [INFO] 23.9
# INFO:strategy:22.85
# 2015-09-08 00:00:00 strategy [INFO] 22.85
# INFO:strategy:23.15
# 2015-09-09 00:00:00 strategy [INFO] 23.15
# INFO:strategy:22.65
# 2015-09-10 00:00:00 strategy [INFO] 22.65
# INFO:strategy:22.6
# 2015-09-11 00:00:00 strategy [INFO] 22.6
# INFO:strategy:22.5
# 2015-09-14 00:00:00 strategy [INFO] 22.5
# INFO:strategy:20.95
# 2015-09-15 00:00:00 strategy [INFO] 20.95
# INFO:strategy:19.6
# 2015-09-16 00:00:00 strategy [INFO] 19.6
# INFO:strategy:20.2
# 2015-09-17 00:00:00 strategy [INFO] 20.2
# INFO:strategy:21.0
# 2015-09-18 00:00:00 strategy [INFO] 21.0
# INFO:strategy:20.2
# 2015-09-21 00:00:00 strategy [INFO] 20.2
# INFO:strategy:21.05
# 2015-09-22 00:00:00 strategy [INFO] 21.05
# INFO:strategy:20.75
# 2015-09-23 00:00:00 strategy [INFO] 20.75
# INFO:strategy:21.2
# 2015-09-24 00:00:00 strategy [INFO] 21.2
# INFO:strategy:21.55
# 2015-09-25 00:00:00 strategy [INFO] 21.55
# INFO:strategy:22.25
# 2015-09-28 00:00:00 strategy [INFO] 22.25
# INFO:strategy:22.35
# 2015-09-29 00:00:00 strategy [INFO] 22.35
# INFO:strategy:22.0
# 2015-09-30 00:00:00 strategy [INFO] 22.0
# INFO:strategy:21.55
# 2015-10-01 00:00:00 strategy [INFO] 21.55
# INFO:strategy:20.75
# 2015-10-02 00:00:00 strategy [INFO] 20.75
# INFO:strategy:19.9
# 2015-10-05 00:00:00 strategy [INFO] 19.9
# INFO:strategy:20.35
# 2015-10-06 00:00:00 strategy [INFO] 20.35
# INFO:strategy:19.65
# 2015-10-07 00:00:00 strategy [INFO] 19.65
# INFO:strategy:19.25
# 2015-10-08 00:00:00 strategy [INFO] 19.25
# INFO:strategy:19.3
# 2015-10-09 00:00:00 strategy [INFO] 19.3
# INFO:strategy:18.35
# 2015-10-12 00:00:00 strategy [INFO] 18.35
# INFO:strategy:19.5
# 2015-10-13 00:00:00 strategy [INFO] 19.5
# INFO:strategy:19.74
# 2015-10-14 00:00:00 strategy [INFO] 19.74
# INFO:strategy:18.45
# 2015-10-15 00:00:00 strategy [INFO] 18.45
# INFO:strategy:18.55
# 2015-10-16 00:00:00 strategy [INFO] 18.55
# INFO:strategy:17.7
# 2015-10-19 00:00:00 strategy [INFO] 17.7
# INFO:strategy:18.45
# 2015-10-20 00:00:00 strategy [INFO] 18.45
# INFO:strategy:19.25
# 2015-10-21 00:00:00 strategy [INFO] 19.25
# INFO:strategy:17.69
# 2015-10-22 00:00:00 strategy [INFO] 17.69
# INFO:strategy:18.05
# 2015-10-23 00:00:00 strategy [INFO] 18.05
# INFO:strategy:18.33
# 2015-10-26 00:00:00 strategy [INFO] 18.33
# INFO:strategy:18.03
# 2015-10-27 00:00:00 strategy [INFO] 18.03
# INFO:strategy:17.7
# 2015-10-28 00:00:00 strategy [INFO] 17.7
# INFO:strategy:17.84
# 2015-10-29 00:00:00 strategy [INFO] 17.84
# INFO:strategy:18.18
# 2015-10-30 00:00:00 strategy [INFO] 18.18
# INFO:strategy:17.51
# 2015-11-02 00:00:00 strategy [INFO] 17.51
# INFO:strategy:17.8
# 2015-11-03 00:00:00 strategy [INFO] 17.8
# INFO:strategy:18.16
# 2015-11-04 00:00:00 strategy [INFO] 18.16
# INFO:strategy:17.7
# 2015-11-05 00:00:00 strategy [INFO] 17.7
# INFO:strategy:17.37
# 2015-11-06 00:00:00 strategy [INFO] 17.37
# INFO:strategy:18.09
# 2015-11-09 00:00:00 strategy [INFO] 18.09
# INFO:strategy:17.7
# 2015-11-10 00:00:00 strategy [INFO] 17.7
# INFO:strategy:18.0
# 2015-11-11 00:00:00 strategy [INFO] 18.0
# INFO:strategy:19.12
# 2015-11-12 00:00:00 strategy [INFO] 19.12
# INFO:strategy:20.15
# 2015-11-13 00:00:00 strategy [INFO] 20.15
# INFO:strategy:18.45
# 2015-11-16 00:00:00 strategy [INFO] 18.45
# INFO:strategy:18.77
# 2015-11-17 00:00:00 strategy [INFO] 18.77
# INFO:strategy:18.35
# 2015-11-18 00:00:00 strategy [INFO] 18.35
# INFO:strategy:18.85
# 2015-11-19 00:00:00 strategy [INFO] 18.85
# INFO:strategy:18.3
# 2015-11-20 00:00:00 strategy [INFO] 18.3
# INFO:strategy:17.8
# 2015-11-23 00:00:00 strategy [INFO] 17.8
# INFO:strategy:18.3
# 2015-11-24 00:00:00 strategy [INFO] 18.3
# INFO:strategy:17.75
# 2015-11-25 00:00:00 strategy [INFO] 17.75
# INFO:strategy:18.05
# 2015-11-27 00:00:00 strategy [INFO] 18.05
# INFO:strategy:17.8
# 2015-11-30 00:00:00 strategy [INFO] 17.8
# INFO:strategy:17.1
# 2015-12-01 00:00:00 strategy [INFO] 17.1
# INFO:strategy:17.55
# 2015-12-02 00:00:00 strategy [INFO] 17.55
# INFO:strategy:18.5
# 2015-12-03 00:00:00 strategy [INFO] 18.5
# INFO:strategy:17.3
# 2015-12-04 00:00:00 strategy [INFO] 17.3
# INFO:strategy:17.5
# 2015-12-07 00:00:00 strategy [INFO] 17.5
# INFO:strategy:18.3
# 2015-12-08 00:00:00 strategy [INFO] 18.3
# INFO:strategy:19.02
# 2015-12-09 00:00:00 strategy [INFO] 19.02
# INFO:strategy:19.1
# 2015-12-10 00:00:00 strategy [INFO] 19.1
# INFO:strategy:21.95
# 2015-12-11 00:00:00 strategy [INFO] 21.95
# INFO:strategy:20.42
# 2015-12-14 00:00:00 strategy [INFO] 20.42
# INFO:strategy:18.9
# 2015-12-15 00:00:00 strategy [INFO] 18.9
# INFO:strategy:18.1
# 2015-12-16 00:00:00 strategy [INFO] 18.1
# INFO:strategy:19.3
# 2015-12-17 00:00:00 strategy [INFO] 19.3
# INFO:strategy:20.4
# 2015-12-18 00:00:00 strategy [INFO] 20.4
# INFO:strategy:18.81
# 2015-12-21 00:00:00 strategy [INFO] 18.81
# INFO:strategy:17.85
# 2015-12-22 00:00:00 strategy [INFO] 17.85
# INFO:strategy:17.9
# 2015-12-23 00:00:00 strategy [INFO] 17.9
# INFO:strategy:18.25
# 2015-12-24 00:00:00 strategy [INFO] 18.25
# INFO:strategy:17.8
# 2015-12-28 00:00:00 strategy [INFO] 17.8
# INFO:strategy:17.5
# 2015-12-29 00:00:00 strategy [INFO] 17.5
# INFO:strategy:18.3
# 2015-12-30 00:00:00 strategy [INFO] 18.3
# INFO:strategy:18.5
# 2015-12-31 00:00:00 strategy [INFO] 18.5
# INFO:strategy:19.8
# 2016-01-04 00:00:00 strategy [INFO] 19.8
# INFO:strategy:19.45
# 2016-01-05 00:00:00 strategy [INFO] 19.45
# INFO:strategy:20.34
# 2016-01-06 00:00:00 strategy [INFO] 20.34
# INFO:strategy:23.54
# 2016-01-07 00:00:00 strategy [INFO] 23.54
# INFO:strategy:25.25
# 2016-01-08 00:00:00 strategy [INFO] 25.25
# INFO:strategy:23.45
# 2016-01-11 00:00:00 strategy [INFO] 23.45
# INFO:strategy:22.05
# 2016-01-12 00:00:00 strategy [INFO] 22.05
# INFO:strategy:24.75
# 2016-01-13 00:00:00 strategy [INFO] 24.75
# INFO:strategy:23.55
# 2016-01-14 00:00:00 strategy [INFO] 23.55
# INFO:strategy:26.5
# 2016-01-15 00:00:00 strategy [INFO] 26.5
# INFO:strategy:25.85
# 2016-01-19 00:00:00 strategy [INFO] 25.85
# INFO:strategy:28.3
# 2016-01-20 00:00:00 strategy [INFO] 28.3

# %% [markdown]
# ## TO-DO: Incorporate VIX, multiple VIX futures and calculate VRP
